# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.who.int/news-room/fact-sheets/detail/mental-health-strengthening-our-response')

# %%
soup = BeautifulSoup(r.content, 'html.parser')
soup
# Out:
#  <!DOCTYPE html>
#  <html lang="en"> <head> <!-- head to scrape:on --> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	Mental health
# ...

# %%
soup.title
# Out:
# <title>
# 	Mental health
# </title>

# %%
text = soup.find_all(class_="sf_colsIn container")
text
# Out:
# [<div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container">
#  <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="TopHeader_TD9F2A204012_Col00">
#  </div>
#  <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-4" data-placeholder-label="Geo Navigation" data-sf-element="Geo Navigation">
#  <div id="sf-geo-navigation-container">
#  <nav aria-label="Regions" class="sf-geo-navigation">
#  <ul class="sf-primary-geo-navigation">
#  <li class="active sf-no-logo">
#  <a class="mobile nav-logo" href="https://www.who.int/">
#  <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue1820eae93c154e37b2588ab90fdbc17e.svg?sfvrsn=aaed4f35_20"/>
#  </a>
#  <a class="desktop" href="https://www.who.int/">Global</a>
#  </li>
#  <li class="has-children">
#  <a href="#">Regions</a>
#  <div class="sf-secondary-geo-navigation-container">
# ...

# %%
text = soup.find_all(id="PageContent_T0643CD2A003_Col00")

# %%
text
# Out:
# [<div class="sf_colsIn col-md-8" data-placeholder-label="Body" data-sf-element="Column 1" id="PageContent_T0643CD2A003_Col00">
#  <article class="sf-detail-body-wrapper">
# ...

# %%
text[0].text
# Out:
# '\n\nKey factsGlobally, more than a billion people live with a mental health condition.Affordable, effective and feasible strategies exist to promote, protect and restore mental health.The need for action on mental health is indisputable and urgent.Mental health has intrinsic and instrumental value and is integral to our well-being.OverviewMental health is a state of mental well-being that enables people to cope with the stresses of life, realize their abilities, learn and work well, and contribute to their community. It has intrinsic and instrumental value and is a basic human right. Mental health exists on a complex continuum, which is experienced differently from one person to the next. At any one time, a diverse set of individual, family, community and structural factors may combine to protect or undermine mental health. Although most people are resilient, people who are exposed to adverse circumstances are at higher risk of developing a mental health condition.Mental health cond
# ...

# %%
with open("mental_health.txt", "w", encoding="utf-8") as file:
    file.write(text[0].text)

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Please speak something (English or Burmese)...")
    recognizer.adjust_for_ambient_noise(source)
    audio = recognizer.listen(source)

#try:
#    english_text = recognizer.recognize_google(audio, language="en-US")
#    print("English:", english_text)
#except:
#    print("English: Could not recognize.")

try:
    burmese_text = recognizer.recognize_google(audio, language="my-MM")
    print("Burmese:", burmese_text)
except:
    print("Burmese: Could not recognize.")
# Out:
# Please speak something (English or Burmese)...
# Burmese: ကျနော်ဒီနေ့ခေါင်းကိုက်နေတယ်
